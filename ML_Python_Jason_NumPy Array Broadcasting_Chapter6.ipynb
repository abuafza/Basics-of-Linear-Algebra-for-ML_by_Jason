# %% [markdown]
# Listing 6.1: Example of broadcasting a scalar to a one-dimensional array in NumPy.

# %%
# broadcast scalar to one-dimensional array
from numpy import array
# define array
a = array([1, 2, 3])
print(a)
# define scalar
b = 2
print(b)
# broadcast
c = a + b
print(c)
# Out:
# [1 2 3]
# 2
# [3 4 5]

# %% [markdown]
# Listing 6.3: Example of broadcasting a scalar to a two-dimensional array in NumPy

# %%
# broadcast scalar to two-dimensional array
from numpy import array
# define array
A = array([
[1, 2, 3],
[1, 2, 3]])
print(A)
# define scalar
b = 2
print(b)
# broadcast
C = A + b
print(C)
# Out:
# [[1 2 3]
#  [1 2 3]]
# 2
# [[3 4 5]
#  [3 4 5]]

# %% [markdown]
# Listing 6.5: Example of broadcasting a one-dimensional array to a two-dimensional array in
# NumPy.

# %%
# broadcast one-dimensional array to two-dimensional array
from numpy import array
# define two-dimensional array
A = array([
[1, 2, 3],
[1, 2, 3]])
print(A)
# define one-dimensional array
b = array([1, 2, 3])
print(b)
# broadcast
C = A + b
print(C)
# Out:
# [[1 2 3]
#  [1 2 3]]
# [1 2 3]
# [[2 4 6]
#  [2 4 6]]

# %% [markdown]
# Listing 6.7: Example of broadcasting error in NumPy.

# %%
# broadcasting error
from numpy import array
# define two-dimensional array
A = array([
[1, 2, 3],
[1, 2, 3]])
print(A.shape)
# define one-dimensional array
b = array([1, 2])
print(b.shape)
# attempt broadcast
C = A + b
print(C)
# Out:
# (2, 3)
# (2,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-65a384953995> in <module>()
#      10 print(b.shape)
#      11 # attempt broadcast
# ---> 12 C = A + b
#      13 print(C)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,)
